# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioGarciaGarvi/CelegansLifespanPrediction/blob/main/CelegansLifespanPredictionDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone Github repo

# %%
! git clone https://github.com/AntonioGarciaGarvi/CelegansLifespanPrediction
# Out:
# Cloning into 'CelegansLifespanPrediction'...
# remote: Enumerating objects: 314, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 314 (delta 27), reused 68 (delta 25), pack-reused 238
# Receiving objects: 100% (314/314), 575.21 MiB | 16.24 MiB/s, done.
# Resolving deltas: 100% (179/179), done.
# Checking out files: 100% (232/232), done.

# %% [markdown]
# # Load trained model

# %%
# %cd /content/CelegansLifespanPrediction/Model_files/
# Out:
# /content/CelegansLifespanPrediction/Model_files

# %%
! cat model_pth.tar.bz.* > model_pth.tar.bz
! tar -xvjf model_pth.tar.bz
# Out:
# model.pth

# %%
# %cd /content/CelegansLifespanPrediction
# Out:
# /content/CelegansLifespanPrediction

# %%
import torch
import demo_model
import utils_predict_lifespan
## Load NN model
nw = demo_model.CNN_LSTM(seq_length=57,img_size=256, kernel_s_layer_1=5, kernel_s=5, max1=3, max2=4, max3=2,
                                out_channels_1=4, out_channels_2=8, out_channels_final=16,LSTM_hidden=1024, LSTM_layers=1,
                                LSTM2_hidden=256, LSTM2_layers=1, p=0)
print(nw)
nw.load_state_dict(torch.load('/content/CelegansLifespanPrediction/Model_files/model.pth'))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
nw.to(device)
# Out:
# CNN_LSTM(
#   (conv1): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1))
#   (cnn_bn1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(4, 8, kernel_size=(5, 5), stride=(1, 1))
#   (cnn_bn2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(8, 16, kernel_size=(5, 5), stride=(1, 1))
#   (cnn_bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (LSTM): LSTM(1024, 1024, batch_first=True)
#   (LSTM2): LSTM(1, 256, batch_first=True)
#   (fc1): Linear(in_features=72960, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=2000, bias=True)
#   (bn2): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=2000, out_features=750, bias=True)
# ...

# %% [markdown]
# # Prediction

# %%
nw.eval()
conddir = '/content/CelegansLifespanPrediction/Dataset_demo/LS13V1condA' # dataset folder
gaps_days = [9, 10, 16, 17, 20, 23, 24] # 
idx_ini = 13 # first day in which prediction can be made
utils_predict_lifespan.predict_lifespan_curve(conddir, gaps_days, idx_ini, nw, device)
# Out:
# --------------------------------------------------------------
# LS13V1condA
# --------------------------------------------------------------
#
# --> Number of inputs: 13
# /content/CelegansLifespanPrediction/Dataset_demo/LS13V1condA/Lifespan13 V1 cond=A pla=1
# /content/CelegansLifespanPrediction/utils_predict_lifespan.py:24: RuntimeWarning: invalid value encountered in power
#   return np.exp(-(x / b) ** a)
# /content/CelegansLifespanPrediction/Dataset_demo/LS13V1condA/Lifespan13 V1 cond=A pla=2
# /content/CelegansLifespanPrediction/Dataset_demo/LS13V1condA/Lifespan13 V1 cond=A pla=3
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/minpack.py:834: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /content/CelegansLifespanPrediction/Dataset_demo/LS13V1condA/Lifespan13 V1 cond=A pla=4
# /content/CelegansLifespanPrediction/Dataset_demo/LS13V1condA/Lifespan13 V1 cond=A pla=5
# ...
